# %%
import uproot
import ROOT
import uproot
import vector
vector.register_awkward()
# import uproot_methods
import pandas as pd
# import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import awkward as ak
import hist
from hist import Hist,axis

# %%
events = uproot.open("combined.root:GluGluToHHTo2G4Q_node_cHHH0_13TeV_HHWWggTag_1")
events_Re = uproot.open("GluGluToRadionToHHTo2G4Q_M300.root:Events")

# %%
events["GEN_Quark_0_pt"!=-99].array()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_16596/2677669526.py in <module>
# ----> 1 events["GEN_Quark_0_pt"!=-99].array()
#
# /eos/user/z/zhenxuan/miniconda3/envs/HHWWGG/lib/python3.7/site-packages/uproot/behaviors/TBranch.py in __getitem__(self, where)
#    1893         else:
#    1894             raise TypeError(
# -> 1895                 "where must be an integer or a string, not {0}".format(repr(where))
#    1896             )
#    1897
#
# TypeError: where must be an integer or a string, not True

# %%
np.log(999)
# Out:
# 6.906754778648554

# %%
minx = 0
maxx =100
pick_color = list(mcolors.TABLEAU_COLORS)
a = ["FullyResolved_Jet1_pt","FullyResolved_Jet2_pt","FullyResolved_Jet3_pt","FullyResolved_Jet4_pt"]
for i in range(0,4):
    plt.hist(events_Re[a[i]].array(),
             bins=100,
                range=(minx,maxx),
                label=a[i],
                fill=False,
                linewidth=2,
                edgecolor=pick_color[i],
                histtype='step'
                )
# plt.xlabel("mass")
plt.xlabel(r"$pT(GeV)$")
plt.ylabel("number of events")
plt.title("Order with PT")
plt.axvline(x = 10, color = 'r',label="PT = 10",linestyle ="--")
plt.legend(loc=1,fontsize=10)
# plt.legend(fontsize=7,bbox_to_anchor=(1,1))

# %%
events_all = uproot.open("combined.root")

# %%
events_Re.classnames()
# Out:
# {'Events;4': 'TTree',
#  'Events;3': 'TTree',
#  'TotalEvents;1': 'TH1F',
#  'totalCutFlow_FH;1': 'TH1F',
#  'Radion_Cutflow;1': 'TH1F',
#  'Ak4JetsCut;1': 'TH1F',
#  'totalCutFlow_FH_GENMatch;1': 'TH1F',
#  'totalCutFlow_SL;1': 'TH1F',
#  'eventNumber;1': 'TH1F'}

# %%
events_Re["GEN_W1_pT"].array()
# Out:
# <Array [23.1, 38.8, 34.8, ... 26.8, 98.2, 24.1] type='118818 * float32'>

# %%
import ROOT
from ROOT import TFile

# %%
tfile = TFile.Open("GluGluToRadionToHHTo2G4Q_M300.root")
input_ttree = tfile.Get("Events")
nentries = input_ttree.GetEntries()

# %%
for entry in range(1):
    input_ttree.GetEntry(entry)
    quark0 = Jet()
    quark0.SetLorentzVector(input_ttree.GEN_Q1_pT,input_ttree.GEN_Q1_eta,input_ttree.GEN_Q1_phi,input_ttree.GEN_Q1_mass)
quark0.Pt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_16596/1966162478.py in <module>
#       2     input_ttree.GetEntry(entry)
#       3 #     quark0 = ROOT.TLorentzVector()
# ----> 4     quark0.SetLorentzVector(input_ttree.GEN_Q1_pT,input_ttree.GEN_Q1_eta,input_ttree.GEN_Q1_phi,input_ttree.GEN_Q1_mass)
#       5 quark0.Pt()
#
# AttributeError: 'TLorentzVector' object has no attribute 'SetLorentzVector'

# %%
for entry in range(1):
    input_ttree.GetEntry(entry)
    print(input_ttree.GEN_W1_pT)
# Out:
# 23.125
# 38.75
# 34.75
# 15.75
# 55.25
# 57.5
# 248.5
# 63.25
# 74.75
# 78.25
# 51.75
# 76.75
# 35.125
# 24.6875
# 72.0
# 83.25
# 88.0
# 36.75
# 45.125
# 43.0
# 68.5
# 33.75
# 103.5
# 22.25
# 54.875
# 31.8125
# 46.5
# 50.625
# 110.5
# 68.25
# 32.25
# 59.375
# 50.5
# 13.53125
# 91.25
# 14.78125
# 31.375
# 35.125
# 44.125
# 56.0
# 57.25
# 40.875
# 46.0
# 56.25
# 51.0
# 41.75
# 50.875
# 17.75
# 60.5
# 81.0
# 53.125
# 199.5
# 79.5
# 5.03125
# 31.625
# 68.75
# 73.5
# 70.75
# 68.5
# 72.75
# 35.125
# 35.75
# 48.125
# 82.0
# 28.3125
# 69.25
# 29.9375
# 27.75
# 110.25
# 18.625
# 62.375
# 25.3125
# 64.25
# 82.5
# 20.375
# 59.0
# 19.5
# 40.125
# 46.875
# 31.4375
# 57.5
# 34.0
# 127.0
# 21.5
# 22.5625
# 48.125
# 90.0
# 74.5
# 54.25
# 45.75
# 60.5
# 104.0
# 48.75
# 48.0
# 15.875
# 61.0
# 47.25
# 142.5
# 81.25
# 21.1875
# 26.9375
# 45.75
# 27.6875
# 67.0
# 11.875
# 16.4375
# 40.5
# 22.625
# 85.5
# 78.0
# 36.375
# 44.75
# 24.5625
# 27.4375
# 85.0
# 29.1875
# 48.25
# 116.75
# 25.625
# 47.5
# 60.75
# ...

# %%
# events.show()
events_Re.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# run                  | uint32_t                 | AsDtype('>u4')
# ls                   | uint32_t                 | AsDtype('>u4')
# evt                  | uint64_t                 | AsDtype('>u8')
# nPV                  | float                    | AsDtype('>f4')
# nPU_mean             | float                    | AsDtype('>f4')
# genWeight            | float                    | AsDtype('>f4')
# puWeight             | float                    | AsDtype('>f4')
# puWeight_Up          | float                    | AsDtype('>f4')
# puWeight_Down        | float                    | AsDtype('>f4')
# L1PFWeight           | float                    | AsDtype('>f4')
# L1PFWeight_Up        | float                    | AsDtype('>f4')
# L1PFWeight_Down      | float                    | AsDtype('>f4')
# ...

# %%
events["Leading_GEN_W_pt"].array()
# Out:
# <Array [65.6, 56.9, 167, ... 107, 106, 82.7] type='65535 * float32'>

# %%
a = np.array([ [1,2,3,4,5],[1,2,32145,2134,54],[23,4,325,234,1435],[234,3,21,34,534],[234,245,345,36,7,5] ])
# Out:
# /afs/cern.ch/user/z/zhenxuan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
a = np.array([[1,5,2] , [2,4,3]])
a.flatten()
# Out:
# array([1, 5, 2, 2, 4, 3])

# %%
k = np.partition(a.flatten(),2)
value = np.partition(a.flatten(),2).item(2)
index = np.where(k == value)
index[1][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_18555/1058788877.py in <module>
#       2 value = np.partition(a.flatten(),2).item(2)
#       3 index = np.where(k == value)
# ----> 4 index[1][0]
#
# IndexError: tuple index out of range

# %%
b = np.partition(a.flatten(),0).item(0)
b

# %%
import ROOT
from ROOT import TTree, TFile

# %%
# tfile = TFile.Open("a.root","recreate")
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
jet1_pt_correct = ROOT.TH1F('jet1_pt_correct', 'Jet pT (correct perm.)', 50,0,200)
# for i in range(100):
#     jet1_pt_correct.Fill()
    
jet1_pt_correct.Scale(1/jet1_pt_correct.Integral(0,jet1_pt_correct.GetNbinsX()+1))
jet1_pt_correct.Draw()
c.Draw()

# jet1_pt_correct.Write()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_18555/1874868423.py in <module>
#       5 #     jet1_pt_correct.Fill()
#       6
# ----> 7 jet1_pt_correct.Scale(1/jet1_pt_correct.Integral(0,jet1_pt_correct.GetNbinsX()+1))
#       8 jet1_pt_correct.Draw()
#       9 c.Draw()
#
# ZeroDivisionError: float division by zero
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
# Warning in <TFile::Append>: Replacing existing TH1: jet1_pt_correct (Potential memory leak).

# %%
jet1_pt_correct.Get
# Out:
# 4.0

# %%
a = uproot.open("a.root")

# %%
a.keys()
# Out:
# []

# %%
import ROOT
f = ROOT.TF1("f1", "sin(x)/x", 0., 10.)
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
f.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
