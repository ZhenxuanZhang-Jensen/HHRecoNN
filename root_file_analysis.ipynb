# %%
import uproot

# %%
events = uproot.open("combined.root:GluGluToHHTo2G4Q_node_cHHH0_13TeV_HHWWggTag_1")

# %%
events_all = uproot.open("combined.root")

# %%
events_all.classnames()
# Out:
# {'GluGluToHHTo2G4Q_node_cHHH0_13TeV_HHWWggTag_1;1': 'TTree'}

# %%
events.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# candidate_id         | int32_t                  | AsDtype('>i4')
# weight               | float                    | AsDtype('>f4')
# CMS_hgg_mass         | float                    | AsDtype('>f4')
# sigmaMoM_decorr      | float                    | AsDtype('>f4')
# dZ                   | float                    | AsDtype('>f4')
# centralObjectWeight  | float                    | AsDtype('>f4')
# passPS               | float                    | AsDtype('>f4')
# passPhotonSels       | float                    | AsDtype('>f4')
# mW1_40To160          | float                    | AsDtype('>f4')
# mW1_65To105          | float                    | AsDtype('>f4')
# mW2_0To160           | float                    | AsDtype('>f4')
# mH_105To160          | float                    | AsDtype('>f4')
# ...

# %%
events["Leading_GEN_W_pt"].array()
# Out:
# <Array [65.6, 56.9, 167, ... 107, 106, 82.7] type='65535 * float32'>

# %%
a = np.array([ [1,2,3,4,5],[1,2,32145,2134,54],[23,4,325,234,1435],[234,3,21,34,534],[234,245,345,36,7,5] ])
# Out:
# /afs/cern.ch/user/z/zhenxuan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
a = np.array([[1,5,2] , [2,4,3]])
a.flatten()
# Out:
# array([1, 5, 2, 2, 4, 3])

# %%
k = np.partition(a.flatten(),2)
value = np.partition(a.flatten(),2).item(2)
index = np.where(k == value)
index[1][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_18555/1058788877.py in <module>
#       2 value = np.partition(a.flatten(),2).item(2)
#       3 index = np.where(k == value)
# ----> 4 index[1][0]
#
# IndexError: tuple index out of range

# %%
b = np.partition(a.flatten(),0).item(0)
b

# %%
import ROOT
from ROOT import TTree, TFile

# %%
# tfile = TFile.Open("a.root","recreate")
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
jet1_pt_correct = ROOT.TH1F('jet1_pt_correct', 'Jet pT (correct perm.)', 50,0,200)
# for i in range(100):
#     jet1_pt_correct.Fill()
    
jet1_pt_correct.Scale(1/jet1_pt_correct.Integral(0,jet1_pt_correct.GetNbinsX()+1))
jet1_pt_correct.Draw()
c.Draw()

# jet1_pt_correct.Write()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/zhenxuan/ipykernel_18555/1874868423.py in <module>
#       5 #     jet1_pt_correct.Fill()
#       6
# ----> 7 jet1_pt_correct.Scale(1/jet1_pt_correct.Integral(0,jet1_pt_correct.GetNbinsX()+1))
#       8 jet1_pt_correct.Draw()
#       9 c.Draw()
#
# ZeroDivisionError: float division by zero
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
# Warning in <TFile::Append>: Replacing existing TH1: jet1_pt_correct (Potential memory leak).

# %%
jet1_pt_correct.Get
# Out:
# 4.0

# %%
a = uproot.open("a.root")

# %%
a.keys()
# Out:
# []

# %%
import ROOT
f = ROOT.TF1("f1", "sin(x)/x", 0., 10.)
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)
f.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
